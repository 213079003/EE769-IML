# %% [markdown]
# #**4. Non-linear dimension reduction:**
# a. Visualize the data from the file DataKPCA.csv.
#
# b. Train KPCA.
#
# c. Plot the variance explained versus KPCA dimensions for up to 10 dimensions.

# %% [markdown]
# ##**Import the libraries**

# %%
from sklearn.decomposition import KernelPCA
from keras.datasets import mnist
from sklearn.datasets import load_iris
from numpy import reshape
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ##**Data Visualization**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#Interpretation for correlation matrix
df = pd.read_csv("/content/drive/MyDrive/DataKPCA.csv")
print(df.corr())
plt.figure(figsize=(10,10))
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
plt.show()
# Out:
#           x1        x2        x3        x4        x5        x6        x7
# x1  1.000000 -0.192768 -0.815308  0.924728  0.444921 -0.617167 -0.567600
# x2 -0.192768  1.000000 -0.333149  0.028781  0.699611 -0.178769  0.564269
# x3 -0.815308 -0.333149  1.000000 -0.862548 -0.831090  0.828093  0.204812
# x4  0.924728  0.028781 -0.862548  1.000000  0.520445 -0.633372 -0.603537
# x5  0.444921  0.699611 -0.831090  0.520445  1.000000 -0.737043  0.330256
# x6 -0.617167 -0.178769  0.828093 -0.633372 -0.737043  1.000000  0.034170
# x7 -0.567600  0.564269  0.204812 -0.603537  0.330256  0.034170  1.000000

# %% [markdown]
# **Observations**
# *   x1 is highly correlated with x3 and x4
# *   x2 is uncorrelated with other features
# *   x3 is highly correlated with x1,x4,x5 and x6
# *   x4 is highly correlated with x1 and x3
# *   x5 is highly correlated with x2 and x3
# *   x6 is highly correlated with x3 and x5
# *   x7 is uncorrelated with other features

# %%
#Interpretation from scatter plot
df = pd.read_csv("/content/drive/MyDrive/DataKPCA.csv")
x=np.arange(0,df.shape[0],1)
plt.figure(figsize=(5,5))
for i in range(df.shape[1]):
  p=str(i+1)
  plt.scatter(x,df.iloc[:,i],label='x'+p)
  plt.legend()

# %% [markdown]
# We can tell from the scatter plot that the features have less variance because they have less variation in the y axis.

# %% [markdown]
# ##**KPCA**

# %%
#Defining kpca function for geting PC's
def kpca(data,no_components,gamma_value):
   pca = KernelPCA(kernel="rbf", n_components=no_components, gamma=gamma_value)
   z = pca.fit_transform(x)
   df = pd.DataFrame(z)
   explained_variance = list(np.var(df, axis=0))
   return z

# %%
x=pd.read_csv("/content/drive/MyDrive/DataKPCA.csv") #reading Data
################################
"""Using the PCA function, we can obtain the first principle components and their mse by subtracting the reconstructed matrix."""
kpca_df_1 = kpca(x,1,0.01)
principal_df1 = pd.DataFrame(kpca_df_1, columns = ['PC1'])
print(principal_df1)
################################
"""Using the PCA function, we can obtain the first two principle components and their mse by subtracting the reconstructed matrix."""
kpca_df_2= kpca(x,2,0.01)
principal_df2 = pd.DataFrame(kpca_df_2, columns = ['PC1','PC2'])
print(principal_df2)
################################
"""Using the PCA function, we can obtain the first three principle components and their mse by subtracting the reconstructed matrix."""
kpca_df_3 = kpca(x,3,0.01)
principal_df3 = pd.DataFrame(kpca_df_3, columns = ['PC1','PC2','PC3'])
print(principal_df2)
################################
"""Using the PCA function, we can obtain the first four principle components and their mse by subtracting the reconstructed matrix."""
kpca_df_4 = kpca(x,4,0.01)
principal_df4 = pd.DataFrame(kpca_df_4, columns = ['PC1','PC2','PC3','PC4'])
print(principal_df4)
################################
"""Using the PCA function, we can obtain the first five principle components and their mse by subtracting the reconstructed matrix."""
kpca_df_5= kpca(x,5,0.01)
principal_df5 = pd.DataFrame(kpca_df_5, columns = ['PC1','PC2','PC3','PC4','PC5'])
print(principal_df5)
################################
"""Using the PCA function, we can obtain the first six principle components and their mse by subtracting the reconstructed matrix."""
kpca_df_6 = kpca(x,6,0.01)
principal_df6 = pd.DataFrame(kpca_df_6, columns = ['PC1','PC2','PC3','PC4','PC5','PC6'])
print(principal_df6)
################################
"""Using the PCA function, we can obtain the first seven principle components and their mse by subtracting the reconstructed matrix."""
kpca_df_7 = kpca(x,7,0.01)
principal_df7 = pd.DataFrame(kpca_df_7, columns = ['PC1','PC2','PC3','PC4','PC5','PC6','PC7'])
print(principal_df7)
################################
"""Using the PCA function, we can obtain the first eight principle components and their mse by subtracting the reconstructed matrix."""
kpca_df_8 = kpca(x,8,0.01)
principal_df8 = pd.DataFrame(kpca_df_8, columns = ['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8'])
print(principal_df8)
################################
"""Using the PCA function, we can obtain the first nine principle components and their mse by subtracting the reconstructed matrix."""
kpca_df_9 =kpca(x,9,0.01)
principal_df1 = pd.DataFrame(kpca_df_9, columns = ['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9'])
print(principal_df1)
################################
"""Using the PCA function, we can obtain the first ten principle components and their mse by subtracting the reconstructed matrix."""
kpca_df_10= kpca(x,10,0.01)
principal_df10 = pd.DataFrame(kpca_df_10, columns = ['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10'])
print(principal_df10)
# Out:
#           PC1
# 0    0.347698
# 1   -0.023577
# 2   -0.137935
# 3    0.640858
# 4   -0.321395
# ..        ...
# 185  0.429103
# 186  0.342772
# 187 -0.266818
# 188 -0.173002
# 189 -0.240773
#
# [190 rows x 1 columns]
#           PC1       PC2
# 0    0.347698 -0.108892
# 1   -0.023577 -0.096505
# 2   -0.137935 -0.140746
# 3    0.640858  0.199756
# 4   -0.321395 -0.004412
# ..        ...       ...
# 185  0.429103  0.096319
# 186  0.342772  0.002240
# 187 -0.266818 -0.029843
# 188 -0.173002 -0.004003
# 189 -0.240773  0.041890
#
# [190 rows x 2 columns]
#           PC1       PC2
# 0    0.347698 -0.108892
# 1   -0.023577 -0.096505
# 2   -0.137935 -0.140746
# 3    0.640858  0.199756
# 4   -0.321395 -0.004412
# ..        ...       ...
# 185  0.429103  0.096319
# 186  0.342772  0.002240
# 187 -0.266818 -0.029843
# 188 -0.173002 -0.004003
# 189 -0.240773  0.041890
#
# [190 rows x 2 columns]
#           PC1       PC2       PC3       PC4
# 0    0.347698 -0.108892  0.017727 -0.026944
# 1   -0.023577 -0.096505 -0.138241  0.009431
# 2   -0.137935 -0.140746 -0.097018 -0.124041
# 3    0.640858  0.199756  0.324110 -0.097751
# 4   -0.321395 -0.004412 -0.062703  0.061323
# ..        ...       ...       ...       ...
# 185  0.429103  0.096319 -0.051596  0.078837
# 186  0.342772  0.002240 -0.070612  0.062036
# 187 -0.266818 -0.029843 -0.117308 -0.067644
# 188 -0.173002 -0.004003 -0.192326 -0.080988
# 189 -0.240773  0.041890 -0.189569 -0.079645
#
# [190 rows x 4 columns]
#           PC1       PC2       PC3       PC4       PC5
# 0    0.347698 -0.108892  0.017727 -0.026944 -0.060477
# 1   -0.023577 -0.096505 -0.138241  0.009431 -0.002667
# 2   -0.137935 -0.140746 -0.097018 -0.124041  0.062408
# 3    0.640858  0.199756  0.324110 -0.097751 -0.028158
# 4   -0.321395 -0.004412 -0.062703  0.061323 -0.005886
# ..        ...       ...       ...       ...       ...
# 185  0.429103  0.096319 -0.051596  0.078837 -0.008612
# 186  0.342772  0.002240 -0.070612  0.062036 -0.034860
# 187 -0.266818 -0.029843 -0.117308 -0.067644  0.035193
#           PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    0.347698 -0.108892  0.017727 -0.026944 -0.060477 -0.031333 -0.033250
# 1   -0.023577 -0.096505 -0.138241  0.009431 -0.002667  0.011562 -0.024498
# 2   -0.137935 -0.140746 -0.097018 -0.124041  0.062408  0.026127 -0.026426
# 3    0.640858  0.199756  0.324110 -0.097751 -0.028158  0.097557 -0.025838
# 4   -0.321395 -0.004412 -0.062703  0.061323 -0.005886  0.046468 -0.021180
# ..        ...       ...       ...       ...       ...       ...       ...
# 185  0.429103  0.096319 -0.051596  0.078837 -0.008612 -0.041121 -0.026986
# 186  0.342772  0.002240 -0.070612  0.062036 -0.034860 -0.035859 -0.033263
# 187 -0.266818 -0.029843 -0.117308 -0.067644  0.035193  0.054648 -0.022964
# 188 -0.173002 -0.004003 -0.192326 -0.080988  0.021171  0.046763 -0.005170
# 189 -0.240773  0.041890 -0.189569 -0.079645  0.011031  0.062909  0.005924
#
#           PC8       PC9
# 0    0.002287  0.000064
# 1    0.013316 -0.000695
# 2    0.019676  0.022024
# 3   -0.016048 -0.070693
# 4    0.009355 -0.025613
# ..        ...       ...
# 185 -0.015030  0.027130
# 186 -0.009012  0.018725
# 187  0.002437  0.015741
# 188 -0.000010  0.012997
# 189 -0.005553  0.018045
#
# [190 rows x 9 columns]
#           PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    0.347698 -0.108892  0.017727 -0.026944 -0.060477 -0.031333 -0.033250
# 1   -0.023577 -0.096505 -0.138241  0.009431 -0.002667  0.011562 -0.024498
# 2   -0.137935 -0.140746 -0.097018 -0.124041  0.062408  0.026127 -0.026426
# 3    0.640858  0.199756  0.324110 -0.097751 -0.028158  0.097557 -0.025838
# 4   -0.321395 -0.004412 -0.062703  0.061323 -0.005886  0.046468 -0.021180
# ..        ...       ...       ...       ...       ...       ...       ...
# 185  0.429103  0.096319 -0.051596  0.078837 -0.008612 -0.041121 -0.026986
# 186  0.342772  0.002240 -0.070612  0.062036 -0.034860 -0.035859 -0.033263
# 187 -0.266818 -0.029843 -0.117308 -0.067644  0.035193  0.054648 -0.022964
# 188 -0.173002 -0.004003 -0.192326 -0.080988  0.021171  0.046763 -0.005170
# 189 -0.240773  0.041890 -0.189569 -0.079645  0.011031  0.062909  0.005924
#
#           PC8       PC9      PC10
# 0    0.002287  0.000064 -0.009162
# 1    0.013316 -0.000695  0.012964
# 2    0.019676  0.022024  0.013651
# 3   -0.016048 -0.070693  0.001591
# 4    0.009355 -0.025613 -0.009420
# ..        ...       ...       ...
# 185 -0.015030  0.027130 -0.010369
# 186 -0.009012  0.018725 -0.001820
# 187  0.002437  0.015741 -0.001042
# 188 -0.000010  0.012997  0.012133
# 189 -0.005553  0.018045  0.004655
#
# [190 rows x 10 columns]

# %%
# Call PCA function
pca = KernelPCA(n_components=10, kernel="rbf")
# Transform features
pca.fit(df)
# Determine explained variance using scikit learn
var_pca = pca.eigenvalues_ / sum(pca.eigenvalues_)
print(sum(var_pca))
# The cumulative sum of eigenvalues will be used to generate a step plot.
# In order to visualise the variance explained by each principal component
cumsum_eig = np.cumsum(var_pca)
#
# Create the visualization plot
#
plt.bar(range(0,len(var_pca)), var_pca, alpha=0.5, align='center', label='Individual explained variance')
plt.step(range(0,len(cumsum_eig)), cumsum_eig, where='mid',label='Cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.tight_layout()
plt.show()
# Out:
# 1.0
